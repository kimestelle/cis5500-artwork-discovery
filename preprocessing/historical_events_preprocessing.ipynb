# %% [markdown]
# # World Events Dataset Preprocessing

# %% [markdown]
# ## imports

# %%
#libraries to handle rdf file format
# %pip install numpy pandas rdflib tqdm
# Out:
# Requirement already satisfied: numpy in /Users/estellekim/miniconda3/lib/python3.13/site-packages (2.2.6)
# Requirement already satisfied: pandas in /Users/estellekim/miniconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: rdflib in /Users/estellekim/miniconda3/lib/python3.13/site-packages (7.4.0)
# Requirement already satisfied: tqdm in /Users/estellekim/miniconda3/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from rdflib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

import re
from pathlib import Path

from rdflib import Graph, Namespace
from rdflib.namespace import RDFS

DCT = Namespace("http://purl.org/dc/terms/")


pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

# %% [markdown]
# ## load data

# %%
def clean_nt_file(src_path, dst_path):
    src_path = Path(src_path)
    dst_path = Path(dst_path)
    
    bad = 0
    total = 0
    
    with src_path.open("r", encoding="utf-8") as fin, dst_path.open("w", encoding="utf-8") as fout:
        for line in fin:
            total += 1
            stripped = line.strip()
            
            # skip empty lines + comment lines
            if not stripped or stripped.startswith("#"):
                continue
            
            # check for correct line ending
            if not stripped.endswith("."):
                bad += 1
                continue
            
            # nt file format: <subject> <predicate> <object> .
            m = re.match(r'^<[^>]+>\s+<[^>]+>\s+.+\s\.\s*$', stripped)
            if not m:
                bad += 1
                continue
            
            fout.write(line)
    
    print(f"{src_path.name}: kept {total - bad} lines, skipped {bad} malformed lines")

# %%
data_dir = Path("./data")

events_path      = data_dir / "events.nt"
first_sent_path  = data_dir / "events_first_sentences.nt"
relations_path   = data_dir / "relations_events_base.nt"
labels_path      = data_dir / "preferred_labels.nt"

events_clean      = data_dir / "events_clean.nt"
first_sent_clean  = data_dir / "events_first_sentences_clean.nt"
relations_clean   = data_dir / "relations_events_base_clean.nt"
labels_clean      = data_dir / "preferred_labels_clean.nt"

clean_nt_file(events_path,     events_clean)
clean_nt_file(first_sent_path, first_sent_clean)
clean_nt_file(relations_path,  relations_clean)
clean_nt_file(labels_path,     labels_clean)
# Out:
# events.nt: kept 8814753 lines, skipped 0 malformed lines
# events_first_sentences.nt: kept 1251819 lines, skipped 0 malformed lines
# relations_events_base.nt: kept 4928718 lines, skipped 0 malformed lines
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 16
#      14 clean_nt_file(first_sent_path, first_sent_clean)
#      15 clean_nt_file(relations_path,  relations_clean)
# ---> 16 clean_nt_file(labels_path,     labels_clean)
#
# Cell In[13], line 29, in clean_nt_file(src_path, dst_path)
#      26             bad += 1
#      27             continue
# ---> 29         fout.write(line)
#      31 print(f"{src_path.name}: kept {total - bad} lines, skipped {bad} malformed lines")
#
# KeyboardInterrupt:

# %%
g_desc = Graph()
g_desc.parse(str(first_sent_clean), format="nt")

len(g_desc)
# Out:
# 1251819

# %%
event_desc = {}

for s, p, o in g_desc:
    # filter out English events since site is tailored for an English-speaking audience
    if getattr(o, "language", None) == "en":
        event_desc[str(s)] = str(o)

len(event_desc)
# Out:
# 371221

# %%
list(event_desc.items())[:5]
# Out:
# [('https://eventkg.l3s.uni-hannover.de/resource/event_148186',
#   "The 2002 Women's British Open was held 8–11 August at the Ailsa Course at Turnberry Golf Club in South Ayrshire, Scotland."),
#  ('https://eventkg.l3s.uni-hannover.de/resource/event_1011202',
#   'Local elections were held in Baringo County on 4 March 2013 to elect a Governor and County Assembly.'),
#  ('https://eventkg.l3s.uni-hannover.de/resource/event_2794267',
#   'United Nations Security Council resolution 744, adopted without a vote on 25 February 1992, after examining the application of the Republic of San Marino for membership in the United Nations, the Council recommended to the General Assembly that San Marino be admitted.'),
#  ('https://eventkg.l3s.uni-hannover.de/resource/event_1838594',
#   'The Guldbagge for Best Cinematography is a Swedish film award presented annually by the Swedish Film Institute as part of the Guldbagge Awards to cinematographers working in the Swedish motion picture industry.'),
#  ('https://eventkg.l3s.uni-hannover.de/resource/event_141408',
#   'The Iranian Revolution, or the Islamic Revolution, refers to a series of events that culminated in the overthrow of the Pahlavi dynasty in 1979.')]

# %%
# regex helpers for weird bracketed urls in nt files
# <s> <p> "text"@lang .
literal_pat = re.compile(
    r'^<([^>]+)>\s+<([^>]+)>\s+"(.*)"@([a-zA-Z\-]+)\s+\.\s*$'
)

# <s> <p> "2020-09-27"^^<...> .
date_pat = re.compile(
    r'^<([^>]+)>\s+<([^>]+)>\s+"([^"]+)"\^\^<[^>]+>\s+\.\s*$'
)

# Descriptions from events_first_sentences_clean.nt
first_sent_rows = []

with first_sent_clean.open("r", encoding="utf-8") as f:
    for line in f:
        m = literal_pat.match(line.strip())
        if not m:
            continue
        subj, pred, text, lang = m.groups()
        if pred == "http://purl.org/dc/terms/description" and lang == "en":
            first_sent_rows.append({
                "EventIRI": subj,
                "Description": text
            })

event_desc = pd.DataFrame(first_sent_rows)
print("event_desc rows:", len(event_desc))
display(event_desc.head())

# Event titles from events_clean.nt
title_rows = []

with events_clean.open("r", encoding="utf-8") as f:
    for line in f:
        m = literal_pat.match(line.strip())
        if not m:
            continue
        subj, pred, text, lang = m.groups()
        if pred == "http://www.w3.org/2000/01/rdf-schema#label" and lang == "en":
            title_rows.append({
                "EventIRI": subj,
                "Title": text
            })

event_labels = pd.DataFrame(title_rows)
print("event_labels rows:", len(event_labels))
display(event_labels.head())

# labels from preferred_labels_clean.nt
label_rows = []

with labels_clean.open("r", encoding="utf-8") as f:
    for line in f:
        m = literal_pat.match(line.strip())
        if not m:
            continue
        subj, pred, text, lang = m.groups()
        if pred == "http://www.w3.org/2004/02/skos/core#prefLabel" and lang == "en":
            label_rows.append({
                "ResourceIRI": subj,
                "PrefLabel": text
            })

pref_labels = pd.DataFrame(label_rows)
print("pref_labels rows:", len(pref_labels))
display(pref_labels.head())

# dates, start and end from relations_events_base_clean.nt
start_rows = []
end_rows   = []

with relations_clean.open("r", encoding="utf-8") as f:
    for line in f:
        m = date_pat.match(line.strip())
        if not m:
            continue
        subj, pred, date_str = m.groups()
        if pred == "http://semanticweb.cs.vu.nl/2009/11/sem/hasBeginTimeStamp":
            start_rows.append({
                "EventIRI": subj,
                "StartDate": date_str
            })
        elif pred == "http://semanticweb.cs.vu.nl/2009/11/sem/hasEndTimeStamp":
            end_rows.append({
                "EventIRI": subj,
                "EndDate": date_str
            })

event_start = pd.DataFrame(start_rows)
event_end   = pd.DataFrame(end_rows)

print("event_start rows:", len(event_start))
print("event_end rows:", len(event_end))
display(event_start.head())
display(event_end.head())

# join into single HistoricalEvents table
events = (
    event_labels
    .merge(event_desc, on="EventIRI", how="left")
    .merge(event_start, on="EventIRI", how="left")
    .merge(event_end, on="EventIRI", how="left")
)

# Add integer EventID
events["EventID"] = range(1, len(events) + 1)

# Convert to datetime safely (weird future years that python can't handle become NaT)
events["StartDate"] = pd.to_datetime(events["StartDate"], errors="coerce")
events["EndDate"]   = pd.to_datetime(events["EndDate"], errors="coerce")
events["StartYear"] = events["StartDate"].dt.year
events["EndYear"]   = events["EndDate"].dt.year

print("HistoricalEvents shape:", events.shape)
display(events.head())

# save to csv files
events.to_csv("HistoricalEvents.csv", index=False)
event_desc.to_csv("EventDescriptions.csv", index=False)
event_labels.to_csv("EventLabels.csv", index=False)
pref_labels.to_csv("PreferredLabels.csv", index=False)

print("intermediate csvs created!")
# Out:
# Using files:
#   descriptions: data/events_first_sentences_clean.nt
#   events: data/events.nt
#   pref labels: data/preferred_labels_clean.nt
#   relations: data/relations_events_base_clean.nt
# event_desc rows: 371221
#                                             EventIRI                                        Description
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...  Lindsay Davenport and Corina Morariu were the ...
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...  The 2019 China Open was a badminton tournament...
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...  Rehaif v. United States, 588 U.S. ___, was a c...
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...  The 2019 Ken Galluccio Cup will be the 11th ed...
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...  The 2019 Danish Handball Cup, known as Santand...
# event_labels rows: 910482
#                                             EventIRI                                              Title
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...  2018 New Zealand First Party deputy leadership...
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...                                          Happiness
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...                                          happiness
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...                            Data Science Day Berlin
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...                                  Triskaidekaphobia
# pref_labels rows: 21045267
#                                          ResourceIRI                                          PrefLabel
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...              Battle of Tulagi and Gavutu–Tanambogo
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...     South Australian state election in Black, 2018
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...                                             Ech Du
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...                      2021 African Minifootball Cup
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...  2008 Taiwanese United Nations membership refer...
# event_start rows: 720325
# event_end rows: 622970
#                                             EventIRI   StartDate
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...  2020-09-27
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...  2021-01-24
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...  2020-11-03
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...  2021-01-01
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...  2008-05-06
#                                             EventIRI     EndDate
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...  2021-05-30
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...  2021-01-24
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...  2008-05-06
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...  2021-10-18
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...  2021-06-26
# HistoricalEvents shape: (910482, 8)
#                                             EventIRI                                              Title  \
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...  2018 New Zealand First Party deputy leadership...
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...                                          Happiness
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...                                          happiness
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...                            Data Science Day Berlin
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...                                  Triskaidekaphobia
#
#                                          Description  StartDate    EndDate  EventID  StartYear  EndYear
# 0  An election for the parliamentary Deputy leade... 2018-02-27 2018-02-27        1     2018.0   2018.0
# 1  Happiness, in the context of mental or emotion...        NaT        NaT        2        NaN      NaN
# 2  Happiness, in the context of mental or emotion...        NaT        NaT        3        NaN      NaN
# 3                                                NaN 2012-05-01        NaT        4     2012.0      NaN
# 4  Triskaidekaphobia is fear or avoidance of the ...        NaT        NaT        5        NaN      NaN
# intermediate csvs created!

# %% [markdown]
# ## format for final csv

# %%
# 1. load csv
events_raw = pd.read_csv("HistoricalEvents.csv")
print("Raw HistoricalEvents.csv:")
display(events_raw.head())

# 2. Make a copy with only the columns we care about
needed_cols = ["EventID", "Title", "Description", "StartDate", "EndDate"]
events = events_raw[needed_cols].copy()

# 3. Normalize dates to mySQL date format (YYYY-MM-DD)
# errors="coerce" turns invalid dates into NaT
events["StartDate"] = pd.to_datetime(events["StartDate"], errors="coerce").dt.date
events["EndDate"]   = pd.to_datetime(events["EndDate"], errors="coerce").dt.date

# **location column is not in eventKG database?
#filter out rows with nan startdate or enddate
historical_events_sql = events[["EventID", "Title", "StartDate", "EndDate", "Description"]].dropna(subset=["StartDate", "EndDate"]).reset_index(drop=True)

print("Formatted HistoricalEvents table (for SQL):")
display(historical_events_sql.head())

# 6. save to new csv
historical_events_sql.to_csv("historical_events.csv", index=False)
print("finished!")
# Out:
# Raw HistoricalEvents.csv:
#                                             EventIRI                                              Title  \
# 0  https://eventkg.l3s.uni-hannover.de/resource/e...  2018 New Zealand First Party deputy leadership...
# 1  https://eventkg.l3s.uni-hannover.de/resource/e...                                          Happiness
# 2  https://eventkg.l3s.uni-hannover.de/resource/e...                                          happiness
# 3  https://eventkg.l3s.uni-hannover.de/resource/e...                            Data Science Day Berlin
# 4  https://eventkg.l3s.uni-hannover.de/resource/e...                                  Triskaidekaphobia
#
#                                          Description   StartDate     EndDate  EventID  StartYear  EndYear
# 0  An election for the parliamentary Deputy leade...  2018-02-27  2018-02-27        1     2018.0   2018.0
# 1  Happiness, in the context of mental or emotion...         NaN         NaN        2        NaN      NaN
# 2  Happiness, in the context of mental or emotion...         NaN         NaN        3        NaN      NaN
# 3                                                NaN  2012-05-01         NaN        4     2012.0      NaN
# 4  Triskaidekaphobia is fear or avoidance of the ...         NaN         NaN        5        NaN      NaN
# Formatted HistoricalEvents table (for SQL):
#    EventID                                              Title   StartDate     EndDate  \
# 0        1  2018 New Zealand First Party deputy leadership...  2018-02-27  2018-02-27
# 1        7                        Cave Creek Complex Wildfire  2005-01-01  2005-12-31
# 2        8                            Cave Creek Complex fire  2005-01-01  2005-12-31
# 3        9    United Nations Security Council Resolution 1994  2011-06-30  2011-12-31
# 4       10                               World Youth Day 2000  2000-08-15  2000-08-20
#
#                                          Description
# 0  An election for the parliamentary Deputy leade...
# 1  The Cave Creek Complex Wildfire was the third ...
# 2  The Cave Creek Complex Wildfire was the third ...
# 3  United Nations Security Council Resolution 199...
# 4  World Youth Day 2000 was a Catholic youth fest...
# finished!

# %% [markdown]
# ## adding location information (missing from original dataset for some reason)

# %%
#try to extract location information from name or description (find country names)
# %pip install pycountry pandas
import pandas as pd
import pycountry
country_names = [country.name for country in pycountry.countries]
print(country_names[:10]) 
location_list = []
numLocations = 0
historical_events_raw = pd.read_csv("historical_events.csv")
historical_events_raw['Title'] = historical_events_raw['Title'].fillna('No Title Provided')
historical_events_raw['Description'] = historical_events_raw['Description'].fillna('No Description Provided')
for index, row in historical_events_raw.iterrows():
    title = row['Title']
    description = row['Description']
    location_found = 'Location Unknown'
    
    for country in country_names:
        if isinstance(country, str) and (country in title or country in description):
            #check if country is a string
            numLocations += 1
            location_found = country
            break
    
    location_list.append(location_found)
historical_events_raw['Location'] = location_list
display(historical_events_raw.head())
print(f"Number of events with locations: {numLocations}")
historical_events_raw.to_csv("historical_events_with_location.csv", index=False)
# Out:
# Requirement already satisfied: pycountry in /Users/estellekim/miniconda3/lib/python3.13/site-packages (24.6.1)
# Requirement already satisfied: pandas in /Users/estellekim/miniconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/estellekim/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Åland Islands', 'Albania', 'Andorra', 'United Arab Emirates', 'Argentina', 'Armenia']
#    EventID                                              Title   StartDate  \
# 0        1  2018 New Zealand First Party deputy leadership...  2018-02-27
# 1        7                        Cave Creek Complex Wildfire  2005-01-01
# 2        8                            Cave Creek Complex fire  2005-01-01
# 3        9    United Nations Security Council Resolution 1994  2011-06-30
# 4       10                               World Youth Day 2000  2000-08-15
#
#       EndDate                                        Description  \
# 0  2018-02-27  An election for the parliamentary Deputy leade...
# 1  2005-12-31  The Cave Creek Complex Wildfire was the third ...
# 2  2005-12-31  The Cave Creek Complex Wildfire was the third ...
# 3  2011-12-31  United Nations Security Council Resolution 199...
# 4  2000-08-20  World Youth Day 2000 was a Catholic youth fest...
#
#            Location
# 0       New Zealand
# 1  Location Unknown
# 2  Location Unknown
# 3  Location Unknown
# 4             Italy
# Number of events with locations: 179444

# %%
#count nulls in every column check
null_counts = historical_events_raw.isnull().sum()
print("Null counts in each column:")
print(null_counts)
# Out:
# Null counts in each column:
# EventID        0
# Title          0
# StartDate      0
# EndDate        0
# Description    0
# Location       0
# dtype: int64

# %%
#create Keywords column by extracting keywords from Title and Description
csv_path = "historical_events_with_location.csv"
import re
import pandas as pd
def extract_keywords(text):
    if not isinstance(text, str):
        text = ""
    text = text.lower()
    #remove punctuation and symbols
    text = re.sub(r'[^\w\s]', '', text)
    words = text.split()
    #remove common words
    stop_words = set(['the', 'and', 'is', 'in', 'to', 'of', 'a', 'for', 'on', 'with', 'as', 'by', 'an', 'at', 'from'])
    keywords = [word for word in words if word not in stop_words]
    return ', '.join(keywords)
#create new Keywords column
historical_events = pd.read_csv(csv_path)
historical_events["Keywords"] = historical_events.apply(
    lambda row: extract_keywords(
        str(row.get("Title", "") or "") + " " + str(row.get("Description", "") or "")
    ),
    axis=1
)
display(historical_events.head())
historical_events.to_csv("historical_events_final.csv", index=False)
# Out:
#    EventID                                              Title   StartDate  \
# 0        1  2018 New Zealand First Party deputy leadership...  2018-02-27
# 1        7                        Cave Creek Complex Wildfire  2005-01-01
# 2        8                            Cave Creek Complex fire  2005-01-01
# 3        9    United Nations Security Council Resolution 1994  2011-06-30
# 4       10                               World Youth Day 2000  2000-08-15
#
#       EndDate                                        Description     Location  \
# 0  2018-02-27  An election for the parliamentary Deputy leade...  New Zealand
# 1  2005-12-31  The Cave Creek Complex Wildfire was the third ...          NaN
# 2  2005-12-31  The Cave Creek Complex Wildfire was the third ...          NaN
# 3  2011-12-31  United Nations Security Council Resolution 199...          NaN
# 4  2000-08-20  World Youth Day 2000 was a Catholic youth fest...        Italy
#
#                                             Keywords
# 0  2018, new, zealand, first, party, deputy, lead...
# 1  cave, creek, complex, wildfire, cave, creek, c...
# 2  cave, creek, complex, fire, cave, creek, compl...
# 3  united, nations, security, council, resolution...
# 4  world, youth, day, 2000, world, youth, day, 20...

# %%
# create historical event keywords csv
#split keywords into separate rows
historical_events = pd.read_csv("historical_events_final.csv")
event_keyword_rows = []
for index, row in historical_events.iterrows():
    event_id = row["EventID"]
    keywords = str(row["Keywords"]).split(", ")
    for keyword in keywords:
        if keyword:  #no empty keywords
            event_keyword_rows.append({
                "EventID": event_id,
                "Keyword": keyword
            })
event_keywords = pd.DataFrame(event_keyword_rows)
print("HistoricalEventKeywords shape:", event_keywords.shape)
display(event_keywords.head())
event_keywords.to_csv("historical_event_keywords.csv", index=False)
# Out:
# HistoricalEventKeywords shape: (8624098, 2)
#    EventID  Keyword
# 0        1     2018
# 1        1      new
# 2        1  zealand
# 3        1    first
# 4        1    party

# %%
#keywords from artworks titles and descriptions
artworks = pd.read_csv("artworks_combined.csv")
def extract_artwork_keywords(text):
    if not isinstance(text, str):
        text = ""
    text = text.lower()
    #remove punctuation and symbols
    text = re.sub(r'[^\w\s]', '', text)
    words = text.split()
    #remove common words
    stop_words = set(['the', 'and', 'is', 'in', 'to', 'of', 'a', 'for', 'on', 'with', 'as', 'by', 'an', 'at', 'from'])
    keywords = [word for word in words if word not in stop_words]
    return ', '.join(keywords)
artworks["Keywords"] = artworks.apply(
    lambda row: extract_artwork_keywords(
        str(row.get("Title", "") or "") + " " + str(row.get("Description", "") or "")
    ),
    axis=1
)

artworks.to_csv("artworks_with_keywords.csv", index=False)

#separate table with artwork keywords
artworks = pd.read_csv("artworks_with_keywords.csv")
artwork_keyword_rows = []
for index, row in artworks.iterrows():
    artwork_id = row["ArtworkID"]
    keywords = str(row["Keywords"]).split(", ")
    for keyword in keywords:
        if keyword:  #no empty keywords
            artwork_keyword_rows.append({
                "ArtworkID": artwork_id,
                "Keyword": keyword
            })
artwork_keywords = pd.DataFrame(artwork_keyword_rows)
print("ArtworkKeywords shape:", artwork_keywords.shape)
display(artwork_keywords.head())
artwork_keywords.to_csv("artwork_keywords.csv", index=False)
# Out:
# ArtworkKeywords shape: (2699861, 2)
#    ArtworkID    Keyword
# 0          1  onedollar
# 1          1    liberty
# 2          1       head
# 3          1       coin
# 4          2  tendollar

# %%
import pandas as pd
import re

# 1. Load combined artists from Met + MoMA
artists = pd.read_csv("artists_combined.csv")   # expects a "Name" and "ArtistID" column

# 2. Load your wiki-style bios (the snippet you pasted)
bios = pd.read_csv("wikibio_train_filtered_final-1.csv")  # whatever your file is actually called

# Fix weird column names like "occupation " with a trailing space
bios = bios.rename(columns=lambda c: c.strip())

# Normalize name columns for joining
artists["Name_norm"] = artists["Name"].str.strip().str.lower()
bios["name_norm"] = bios["name"].str.strip().str.lower()

# Join bios onto artists by normalized name
artists_with_bios = artists.merge(
    bios,
    left_on="Name_norm",
    right_on="name_norm",
    how="left",
    suffixes=("", "_bio")
)

print("Artists with bios shape:", artists_with_bios.shape)
display(artists_with_bios[["ArtistID", "Name", "text", "occupation"]].head())
# Out:
# Artists with bios shape: (72102, 16)
#    ArtistID                      Name  \
# 0         1     James Barton Longacre
# 1         2        Christian Gobrecht
# 2         3           Bela Lyon Pratt
# 3         4            Mexican Artist
# 4         5  James Gillinder and Sons
#
#                                                 text occupation
# 0  james barton longacre ( august 11 , 1794 -- ja...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN

# %%
def extract_artist_keywords(text):
    if not isinstance(text, str):
        text = ""
    text = text.lower()
    # remove punctuation and symbols
    text = re.sub(r'[^\w\s]', '', text)
    words = text.split()
    # remove common stop words
    stop_words = {
        'the', 'and', 'is', 'in', 'to', 'of', 'a', 'for', 'on', 'with',
        'as', 'by', 'an', 'at', 'from', 'was', 'are', 'this', 'that',
        'he', 'she', 'they', 'his', 'her', 'their', 'it'
    }
    keywords = [w for w in words if w not in stop_words]
    return ', '.join(keywords)

# build a combined text field for keyword extraction
artists_with_bios["BioText"] = artists_with_bios.apply(
    lambda row: " ".join([
        str(row.get("text", "") or ""),
        str(row.get("occupation", "") or ""),
        str(row.get("nationality", "") or "")
    ]),
    axis=1
)

artists_with_bios["Keywords"] = artists_with_bios["BioText"].map(extract_artist_keywords)

artists_with_bios.to_csv("artists_with_keywords.csv", index=False)
display(artists_with_bios[["ArtistID", "Name", "Keywords"]].head())
# Out:
#    ArtistID                      Name  \
# 0         1     James Barton Longacre
# 1         2        Christian Gobrecht
# 2         3           Bela Lyon Pratt
# 3         4            Mexican Artist
# 4         5  James Gillinder and Sons
#
#                                             Keywords
# 0  james, barton, longacre, august, 11, 1794, jan...
# 1                                      nan, nan, nan
# 2                                      nan, nan, nan
# 3                                      nan, nan, nan
# 4                                      nan, nan, nan

# %%
artists_kw = pd.read_csv("artists_with_keywords.csv")

artist_keyword_rows = []
for _, row in artists_kw.iterrows():
    artist_id = row["ArtistID"]
    keywords = str(row["Keywords"]).split(", ")
    for kw in keywords:
        kw = kw.strip()
        if kw:
            artist_keyword_rows.append({
                "ArtistID": artist_id,
                "Keyword": kw
            })



#delete rows with nan
artists_keyword_rows = [row for row in artist_keyword_rows if pd.notna(row["Keyword"])]

artist_keywords = pd.DataFrame(artist_keyword_rows)

# remove duplicates
artist_keywords = artist_keywords.drop_duplicates().reset_index(drop=True)

print("ArtistKeywords shape:", artist_keywords.shape)
display(artist_keywords.head())

artist_keywords.to_csv("artist_keywords.csv", index=False)
# Out:
# ArtistKeywords shape: (412410, 2)
#    ArtistID   Keyword
# 0         1     james
# 1         1    barton
# 2         1  longacre
# 3         1    august
# 4         1        11

# %%
import pandas as pd

# 1. load keyword csvs
event_keywords   = pd.read_csv("historical_event_keywords.csv")   # columns: EventID, Keyword
artwork_keywords = pd.read_csv("artwork_keywords.csv")            # columns: ArtworkID, Keyword
artist_keywords  = pd.read_csv("artist_keywords.csv")             # columns: ArtistID, Keyword

# 2. all distinct keywords
all_keywords = pd.concat(
    [
        event_keywords["Keyword"],
        artwork_keywords["Keyword"],
        artist_keywords["Keyword"],
    ],
    ignore_index=True
).dropna()

distinct_terms = all_keywords.drop_duplicates().reset_index(drop=True)

distinct_keywords_df = pd.DataFrame({
    "KeywordID": range(1, len(distinct_terms) + 1),
    "Term": distinct_terms
})

print("Distinct Keywords shape:", distinct_keywords_df.shape)
display(distinct_keywords_df.head())

distinct_keywords_df.to_csv("distinct_keywords.csv", index=False)

# 3. add KeywordID to event keywords
event_keywords_with_ids = event_keywords.merge(
    distinct_keywords_df,
    left_on="Keyword",
    right_on="Term",
    how="left"
)

event_keywords_with_ids = event_keywords_with_ids[["EventID", "KeywordID"]]
print("EventKeywords with IDs shape:", event_keywords_with_ids.shape)
display(event_keywords_with_ids.head())
event_keywords_with_ids.to_csv("historical_event_keywords_with_ids.csv", index=False)

# 4. Add KeywordID to artwork keywords
artwork_keywords_with_ids = artwork_keywords.merge(
    distinct_keywords_df,
    left_on="Keyword",
    right_on="Term",
    how="left"
)

artwork_keywords_with_ids = artwork_keywords_with_ids[["ArtworkID", "KeywordID"]]
print("ArtworkKeywords with IDs shape:", artwork_keywords_with_ids.shape)
display(artwork_keywords_with_ids.head())
artwork_keywords_with_ids.to_csv("artwork_keywords_with_ids.csv", index=False)

# 5. Add KeywordID to artist keywords
artist_keywords_with_ids = artist_keywords.merge(
    distinct_keywords_df,
    left_on="Keyword",
    right_on="Term",
    how="left"
)

artist_keywords_with_ids = artist_keywords_with_ids[["ArtistID", "KeywordID"]]
print("ArtistKeywords with IDs shape:", artist_keywords_with_ids.shape)
display(artist_keywords_with_ids.head())
artist_keywords_with_ids.to_csv("artist_keywords_with_ids.csv", index=False)
# Out:
# Distinct Keywords shape: (232277, 2)
#    KeywordID     Term
# 0          1     2018
# 1          2      new
# 2          3  zealand
# 3          4    first
# 4          5    party
# EventKeywords with IDs shape: (8624098, 2)
#    EventID  KeywordID
# 0        1        1.0
# 1        1        2.0
# 2        1        3.0
# 3        1        4.0
# 4        1        5.0
# ArtworkKeywords with IDs shape: (2699861, 2)
#    ArtworkID  KeywordID
# 0          1   117126.0
# 1          1     5800.0
# 2          1     9226.0
# 3          1    35213.0
# 4          2   117127.0
